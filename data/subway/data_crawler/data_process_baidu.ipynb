# %% [markdown]
# # 百度地图地铁数据处理

# %%
import pandas as pd
import numpy as np
import json

# %%
import sys
sys.path.append("../../..")
from secure.db_account import SubwayPrd
from k_libs.db_query import DBOperate

DBO = DBOperate(SubwayPrd)

# %% [markdown]
# ## 字段表

# %%
# 线路字段
line_fields = [
    {'raw': 'lid',
    'processed': 'line_name_full',
    'info': '线路全名'},
    {'raw': 'lb',
    'processed': 'line_name',
    'info': '线路简称'},
    {'raw': 'n',
    'processed': 'num_stations',
    'info': '线路站点数'},
    {'raw': 'loop',
    'processed': 'is_loop',
    'info': '是否环线'},
    {'raw': 'lbx',
    'processed': 'label_x',
    'info': '线路标签X坐标'},
    {'raw': 'lby',
    'processed': 'label_y',
    'info': '线路标签Y坐标'},
    {'raw': 'lbr',
    'processed': 'label_rotation',
    'info': '线路标签旋转角度'},
    {'raw': 'lc',
    'processed': 'line_color',
    'info': '线路颜色'},
    {'raw': 'uid',
    'processed': 'line_uid',
    'info': '线路唯一ID'},
    {'raw': 'uid2',
    'processed': 'line_uid2',
    'info': '线路备用唯一ID'}
]

# %%
# 站点字段
station_fields = [
    {'raw': 'sid',
    'processed': 'station_name',
    'info': '站点名称'},
    {'raw': 'lb',
    'processed': 'station_label',
    'info': '站点标签'},
    {'raw': 'x',
    'processed': 'x',
    'info': '站点X坐标'},
    {'raw': 'y',
    'processed': 'y',
    'info': '站点Y坐标'},
    {'raw': 'rx',
    'processed': 'label_offset_x',
    'info': '站点标签X偏移'},
    {'raw': 'ry',
    'processed': 'label_offset_y',
    'info': '站点标签Y偏移'},
    {'raw': 'st',
    'processed': 'is_station',
    'info': '是否为车站'},
    {'raw': 'ex',
    'processed': 'is_exchange',
    'info': '是否换乘点'},
    {'raw': 'iu',
    'processed': 'is_use',
    'info': '是否在用,true表示该站已开通并运营'},
    {'raw': 'rc',
    'processed': 'is_rail_construction',
    'info': '是否为规划/在建站点'},
    {'raw': 'slb',
    'processed': 'show_label',
    'info': '是否显示标签'},
    {'raw': 'ln',
    'processed': 'lines',
    'info': '所属线路'},
    {'raw': 'uid',
    'processed': 'station_uid',
    'info': '站点唯一ID'},
    {'raw': 'px',
    'processed': 'proj_x',
    'info': '站点投影坐标X'},
    {'raw': 'py',
    'processed': 'proj_y',
    'info': '站点投影坐标Y'}
    ]

# %% [markdown]
# ## 原始数据
# ODS 层（Operational Data Store，操作数据存储层）
#
# 存放业务系统的原始数据，基本不做加工。
#
# 特点：与业务库字段保持一致，保证数据的完整性与可追溯性。
#
# 作用：承接源系统，作为数据仓库的“原材料”。

# %%
sql = """SELECT * FROM ods_subway_baidu WHERE crawler_id=(SELECT MAX(crawler_id) FROM ods_subway_baidu);"""
df_raw = DBO.read_sql(sql)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15923 entries, 0 to 15922
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   line_lid      15923 non-null  object
#  1   line_lb       15923 non-null  object
#  2   line_slb      15923 non-null  object
#  3   line_n        15923 non-null  object
#  4   line_loop     15923 non-null  object
#  5   line_lbx      15923 non-null  object
#  6   line_lby      15923 non-null  object
#  7   line_lbr      15923 non-null  object
#  8   line_lc       15923 non-null  object
#  9   line_uid      15923 non-null  object
#  10  line_uid2     15923 non-null  object
#  11  st_sid        15923 non-null  object
#  12  st_lb         15923 non-null  object
#  13  st_x          15923 non-null  object
#  14  st_y          15923 non-null  object
#  15  st_rx         15923 non-null  object
#  16  st_ry         15923 non-null  object
#  17  st_st         15923 non-null  object
#  18  st_ex         15923 non-null  object
#  19  st_iu         15923 non-null  object
#  20  st_rc         15923 non-null  object
#  21  st_slb        15923 non-null  object
#  22  st_ln         15923 non-null  object
#  23  st_int        15923 non-null  object
#  24  st_uid        15923 non-null  object
#  25  st_px         15923 non-null  object
#  26  st_py         15923 non-null  object
#  27  city_id       15923 non-null  object
#  28  city_name     15923 non-null  object
#  29  city_name_e   15923 non-null  object
#  30  crawler_id    15923 non-null  int64
#  31  crawler_date  15923 non-null  object
#  32  uid           15923 non-null  object
# dtypes: int64(1), object(32)
# memory usage: 4.0+ MB

# %%
df_raw
# Out:
#        line_lid line_lb line_slb line_n line_loop line_lbx line_lby line_lbr  \
# 0      地铁1号线八通线  1号线八通线    False     23     False   -498.9    139.1        0
# 1      地铁1号线八通线  1号线八通线    False     23     False   -498.9    139.1        0
# 2      地铁1号线八通线  1号线八通线    False     23     False   -498.9    139.1        0
# 3      地铁1号线八通线  1号线八通线    False     23     False   -498.9    139.1        0
# 4      地铁1号线八通线  1号线八通线    False     23     False   -498.9    139.1        0
# ...         ...     ...      ...    ...       ...      ...      ...      ...
# 15918       ML4     ML4    False     16     False     -110     1600        0
# 15919       ML4     ML4    False     16     False     -110     1600        0
# 15920       ML4     ML4    False     16     False     -110     1600        0
# 15921       ML4     ML4    False     16     False     -110     1600        0
# 15922       ML4     ML4    False     16     False     -110     1600        0
#
#         line_lc                  line_uid  ... st_int  \
# 0      0xc03935  bce557d6f7fadd4ea5da39b7  ...      3
# 1      0xc03935  bce557d6f7fadd4ea5da39b7  ...      3
# 2      0xc03935  bce557d6f7fadd4ea5da39b7  ...      3
# 3      0xc03935  bce557d6f7fadd4ea5da39b7  ...      3
# 4      0xc03935  bce557d6f7fadd4ea5da39b7  ...      3
# ...         ...                       ...  ...    ...
# 15918  0x77b838  a1bf283eb66e3574c9c3dbb7  ...      2
# 15919  0x77b838  a1bf283eb66e3574c9c3dbb7  ...      2
# 15920  0x77b838  a1bf283eb66e3574c9c3dbb7  ...      2
# 15921  0x77b838  a1bf283eb66e3574c9c3dbb7  ...      2
# 15922  0x77b838  a1bf283eb66e3574c9c3dbb7  ...      2
#
#                          st_uid        st_px       st_py city_id city_name  \
# 0      291c5802f26a751cbca240d9  12935140.04   4825694.5     131        北京
# 1      ad28546df35285eb851541d9   12937624.6  4825645.68     131        北京
# 2      a047555503a5bc5cbc4842d9  12940185.58  4825661.64     131        北京
# 3      a27fa5a23a128501177643d9   12942086.4  4825707.12     131        北京
# 4      53889c15034f2e3f58bbbcde  12944444.84  4825755.15     131        北京
# ...                         ...          ...         ...     ...       ...
# 15918                      None         None        None   51314       马德里
# 15919                      None         None        None   51314       马德里
# 15920  5660ab357cf66173901fc9b7   -417722.43  4872240.68   51314       马德里
# 15921  d79642c2e73da856eedfcab7    -417875.2  4871682.71   51314       马德里
# 15922  469d885ab33af18a09a8d4b7   -418040.71  4871084.42   51314       马德里
#
#       city_name_e crawler_id crawler_date             uid
# 0         beijing     250928   2025-09-28      1312509280
# 1         beijing     250928   2025-09-28      1312509281
# 2         beijing     250928   2025-09-28      1312509282
# 3         beijing     250928   2025-09-28      1312509283
# 4         beijing     250928   2025-09-28      1312509284
# ...           ...        ...          ...             ...
# 15918      madeli     250928   2025-09-28  51314250928445
# 15919      madeli     250928   2025-09-28  51314250928446
# 15920      madeli     250928   2025-09-28  51314250928447
# 15921      madeli     250928   2025-09-28  51314250928448
# 15922      madeli     250928   2025-09-28  51314250928449
#
# [15923 rows x 33 columns]

# %% [markdown]
# ## DWD
# DWD 层（Data Warehouse Detail，明细数据层）
# 在 ODS 的基础上进行清洗、规范化，保留明细粒度的数据。
# 特点：字段标准化（统一命名、数据类型），做一些维度退化或拆分。
# 作用：保证数据“可用”，是最常被下游加工使用的一层。

# %%
def dwd_subway_bd_to_sql(df_raw):
    """
    将百度地铁数据处理为DWD层数据，并存入数据库
    """

    # 对字段重命名
    df_dwd = df_raw.copy()
    df_dwd = df_dwd.rename(columns={
        'line_lid': 'line_name_full',
        'line_lb': 'line_name',
        'line_slb': 'line_show_label',
        'line_loop': 'line_is_loop',
        'line_lbx': 'line_label_x',
        'line_lby': 'line_label_y',
        'line_lbr': 'line_label_rotation',
        'line_lc': 'line_color',
        'st_sid': 'st_name',
        'st_lb': 'st_label',
        'st_rx': 'st_label_offset_x',
        'st_ry': 'st_label_offset_y',
        'st_st': 'st_is_station',
        'st_ex': 'st_is_exchange',
        'st_iu': 'st_is_use',
        'st_rc': 'st_is_rail_construction',
        'st_slb': 'st_show_label',
        'st_ln': 'st_lines',
        'st_px': 'st_proj_x',
        'st_py': 'st_proj_y'}
    )
    # 字段排序
    field_order = [
        'city_id', 'city_name', 'city_name_e',
        # 线路信息
        'line_name_full', 'line_name', 'line_show_label', 'line_n', 'line_is_loop',
        'line_label_x', 'line_label_y', 'line_label_rotation', 'line_color',
        'line_uid', 'line_uid2',
        # 站点信息
        'st_name', 'st_label', 'st_x', 'st_y', 'st_label_offset_x', 'st_label_offset_y',
        'st_is_station', 'st_is_exchange', 'st_is_use', 'st_is_rail_construction',
        'st_show_label', 'st_lines', 'st_int', 'st_uid', 'st_proj_x', 'st_proj_y',
        # 数据采集信息
        'crawler_id', 'crawler_date', 'uid'
    ]
    df_dwd = df_dwd[field_order]
    # 对存在false,true的字段进行处理
    bool_fields = [
        'line_show_label', 'line_is_loop', 'st_is_station', 'st_is_exchange', 'st_is_use', 'st_is_rail_construction', 'st_show_label'
    ]
    df_dwd = df_dwd.copy()
    for field in bool_fields:
        df_dwd[field] = df_dwd[field].map({'True': 1, 'False': 0})
    # 颜色修改为16进制
    df_dwd['line_color'] = df_dwd['line_color'].apply(lambda x: f"#{x[2:]}" if not x.startswith('#') else x)
    
    # 保存到数据库
    DBO.df_to_sql(df_dwd, "dwd_subway_baidu", if_exists="replace")
    print("Data saved to dwd_subway_baidu table.")
    return df_dwd

dwd_subway = dwd_subway_bd_to_sql(df_raw)
dwd_subway.info()
# Out:
# Data saved to dwd_subway_baidu table.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15923 entries, 0 to 15922
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   city_id                  15923 non-null  object
#  1   city_name                15923 non-null  object
#  2   city_name_e              15923 non-null  object
#  3   line_name_full           15923 non-null  object
#  4   line_name                15923 non-null  object
#  5   line_show_label          15923 non-null  int64
#  6   line_n                   15923 non-null  object
#  7   line_is_loop             15923 non-null  int64
#  8   line_label_x             15923 non-null  object
#  9   line_label_y             15923 non-null  object
#  10  line_label_rotation      15923 non-null  object
#  11  line_color               15923 non-null  object
#  12  line_uid                 15923 non-null  object
#  13  line_uid2                15923 non-null  object
#  14  st_name                  15923 non-null  object
#  15  st_label                 15923 non-null  object
#  16  st_x                     15923 non-null  object
#  17  st_y                     15923 non-null  object
#  18  st_label_offset_x        15923 non-null  object
#  19  st_label_offset_y        15923 non-null  object
#  20  st_is_station            15923 non-null  int64
#  21  st_is_exchange           15923 non-null  int64
#  22  st_is_use                15923 non-null  int64
#  23  st_is_rail_construction  15923 non-null  int64
#  24  st_show_label            15865 non-null  float64
#  25  st_lines                 15923 non-null  object
#  26  st_int                   15923 non-null  object
#  27  st_uid                   15923 non-null  object
#  28  st_proj_x                15923 non-null  object
#  29  st_proj_y                15923 non-null  object
#  30  crawler_id               15923 non-null  int64
#  31  crawler_date             15923 non-null  object
#  32  uid                      15923 non-null  object
# dtypes: float64(1), int64(7), object(25)
# memory usage: 4.0+ MB

# %% [markdown]
# ## DWS
# DWS 层（Data Warehouse Summary，汇总数据层）
#
# 在 DWD 基础上，按业务主题和常用维度做聚合统计。
#
# 特点：以主题域为核心（如用户、订单、交易），形成宽表或统计指标。
#
# 作用：减少重复计算，支撑公共分析需求。
#
# 1. 城市表 dws_subway_bd_city
# 2. 线路表 dws_subway_bd_line
# 3. 车站表 dws_subway_bd_st

# %% [markdown]
# ### 城市表

# %%
with open("city_info.json", "r", encoding="utf-8") as f:
    city_info = json.load(f)
city_info_df = pd.DataFrame.from_dict(city_info['cities'])
city_info_df
# Out:
#    city_name english_pinyin_name province_chinese  \
# 0         北京             Beijing              北京市
# 1         上海            Shanghai              上海市
# 2         广州           Guangzhou              广东省
# 3         深圳            Shenzhen              广东省
# 4         重庆           Chongqing              重庆市
# ..       ...                 ...              ...
# 74       莫斯科              Moscow             莫斯科州
# 75       鹿特丹           Rotterdam             南荷兰省
# 76     伊斯坦布尔            Istanbul           伊斯坦布尔省
# 77      巴塞罗那           Barcelona         加泰罗尼亚自治区
# 78       马德里              Madrid           马德里自治区
#
#            province_pinyin_english country_chinese country_english
# 0                      Beijing Shi              中国           China
# 1                     Shanghai Shi              中国           China
# 2                  Guangdong Sheng              中国           China
# 3                  Guangdong Sheng              中国           China
# 4                    Chongqing Shi              中国           China
# ..                             ...             ...             ...
# 74                   Moscow Oblast             俄罗斯          Russia
# 75          South Holland Province              荷兰     Netherlands
# 76               Istanbul Province             土耳其          Turkey
# 77  Catalonia Autonomous Community             西班牙           Spain
# 78             Community of Madrid             西班牙           Spain
#
# [79 rows x 6 columns]

# %%
df_city = dwd_subway[['city_id', 'city_name']].drop_duplicates().reset_index(drop=True)
df_city['city_order'] = df_city.index + 1
df_city
# Out:
#    city_id city_name  city_order
# 0      131        北京           1
# 1      289        上海           2
# 2      257        广州           3
# 3      340        深圳           4
# 4      132        重庆           5
# ..     ...       ...         ...
# 74   65531       莫斯科          75
# 75   52390       鹿特丹          76
# 76   48552     伊斯坦布尔          77
# 77   51271      巴塞罗那          78
# 78   51314       马德里          79
#
# [79 rows x 3 columns]

# %%
df_city = df_city.merge(city_info_df, how='left', on='city_name')
df_city
# Out:
#    city_id city_name  city_order english_pinyin_name province_chinese  \
# 0      131        北京           1             Beijing              北京市
# 1      289        上海           2            Shanghai              上海市
# 2      257        广州           3           Guangzhou              广东省
# 3      340        深圳           4            Shenzhen              广东省
# 4      132        重庆           5           Chongqing              重庆市
# ..     ...       ...         ...                 ...              ...
# 74   65531       莫斯科          75              Moscow             莫斯科州
# 75   52390       鹿特丹          76           Rotterdam             南荷兰省
# 76   48552     伊斯坦布尔          77            Istanbul           伊斯坦布尔省
# 77   51271      巴塞罗那          78           Barcelona         加泰罗尼亚自治区
# 78   51314       马德里          79              Madrid           马德里自治区
#
#            province_pinyin_english country_chinese country_english
# 0                      Beijing Shi              中国           China
# 1                     Shanghai Shi              中国           China
# 2                  Guangdong Sheng              中国           China
# 3                  Guangdong Sheng              中国           China
# 4                    Chongqing Shi              中国           China
# ..                             ...             ...             ...
# 74                   Moscow Oblast             俄罗斯          Russia
# 75          South Holland Province              荷兰     Netherlands
# 76               Istanbul Province             土耳其          Turkey
# 77  Catalonia Autonomous Community             西班牙           Spain
# 78             Community of Madrid             西班牙           Spain
#
# [79 rows x 8 columns]

# %%
dwd_subway_bd_city = df_city

# %% [markdown]
# ### 线路表
# * line_uid有空值，不可用
# * line_name_full 暂无重复值，可以用
# * line_name 有重复值，需处理

# %% [markdown]
# #### 支线名称清洗

# %%
df_line = dwd_subway[['city_id', 'city_name', 'line_name_full', 'line_name', 'line_is_loop', 'line_label_x', 'line_label_y', 'line_label_rotation', 'line_color']].drop_duplicates().reset_index(drop=True)

# %%
# 按city_name, line_name统计line_name出现次数
df_line['line_name_count'] = df_line.groupby(['city_name', 'line_name'])['line_name'].transform('count')
df_line[df_line['line_name_count'] > 1]
# Out:
#     city_id city_name          line_name_full line_name  line_is_loop  \
# 55      257        广州         地铁3号线(海傍-天河客运站)       3号线             0
# 56      257        广州  地铁3号线(体育西路-机场北(2号航站楼))       3号线             0
# 566   65531       莫斯科      Line 4(昆采沃-亚历山大公园)    Line 4             0
# 567   65531       莫斯科           Line 4(国际-基辅)    Line 4             0
# 585   48552     伊斯坦布尔                      M2        M2             0
# 586   48552     伊斯坦布尔                     M2S        M2             0
# 631   51314       马德里                    ML42       ML4             0
# 632   51314       马德里                     ML4       ML4             0
#
#     line_label_x line_label_y line_label_rotation line_color  line_name_count
# 55           230         -300                   0    #EEB56E                2
# 56           -60         -530                   0    #EEB56E                2
# 566         -457         -170                   0    #54c6f2                2
# 567         -380          -80                   0    #54c6f2                2
# 585        -75.6         -691                   0    #0fa249                2
# 586        -75.6         -691                   0    #0fa249                2
# 631         -110         1600                   0    #77b838                2
# 632         -110         1600                   0    #77b838                2

# %%
# 按city_name, line_name_full统计line_name出现次数
df_line['line_name_full_count'] = df_line.groupby(['city_name', 'line_name_full'])['line_name_full'].transform('count')
df_line[df_line['line_name_full_count'] > 1]
# 注意，当下表不为空时，说明line_name_full也有重复，需要进一步处理
# Out:
# Empty DataFrame
# Columns: [city_id, city_name, line_name_full, line_name, line_is_loop, line_label_x, line_label_y, line_label_rotation, line_color, line_name_count, line_name_full_count]
# Index: []

# %%
# 添加line_name_branch，当line_name_count>1时，使用line_name_full
df_line['line_name_branch'] = df_line['line_name']
df_line.loc[df_line['line_name_count'] > 1, 'line_name_branch'] = df_line['line_name_full']
# 删除line_name_full中的“地铁”
df_line['line_name_branch'] = df_line['line_name_branch'].str.replace('地铁', '', regex=False)
df_line
# Out:
#     city_id city_name line_name_full line_name  line_is_loop line_label_x  \
# 0       131        北京       地铁1号线八通线    1号线八通线             0       -498.9
# 1       131        北京          地铁2号线       2号线             1       -175.3
# 2       131        北京          地铁3号线       3号线             0          450
# 3       131        北京       地铁4号线大兴线    4号线大兴线             0       -499.3
# 4       131        北京          地铁5号线       5号线             0           18
# ..      ...       ...            ...       ...           ...          ...
# 628   51314       马德里            ML1       ML1             0          -70
# 629   51314       马德里            ML2       ML2             0         -780
# 630   51314       马德里            ML3       ML3             0        -1800
# 631   51314       马德里           ML42       ML4             0         -110
# 632   51314       马德里            ML4       ML4             0         -110
#
#     line_label_y line_label_rotation line_color  line_name_count  \
# 0          139.1                   0    #c03935                1
# 1           -4.9                   0    #005f98                1
# 2            -55                   0    #942413                1
# 3           -224                   0    #008e9c                1
# 4         -353.9                   0    #a6217f                1
# ..           ...                 ...        ...              ...
# 628         -960                   0    #5086c2                1
# 629         -280                   0    #ea4d81                1
# 630        295.2                   0    #ff6642                1
# 631         1600                   0    #77b838                2
# 632         1600                   0    #77b838                2
#
#      line_name_full_count line_name_branch
# 0                       1           1号线八通线
# 1                       1              2号线
# 2                       1              3号线
# 3                       1           4号线大兴线
# 4                       1              5号线
# ..                    ...              ...
# 628                     1              ML1
# 629                     1              ML2
# 630                     1              ML3
# 631                     1             ML42
# 632                     1              ML4
#
# [633 rows x 12 columns]

# %%
# 检查广州三号线
df_line[df_line['city_name'] == '广州']
# Out:
#    city_id city_name          line_name_full            line_name  \
# 53     257        广州                   地铁1号线                  1号线
# 54     257        广州                   地铁2号线                  2号线
# 55     257        广州         地铁3号线(海傍-天河客运站)                  3号线
# 56     257        广州  地铁3号线(体育西路-机场北(2号航站楼))                  3号线
# 57     257        广州                   地铁4号线                  4号线
# 58     257        广州                   地铁5号线                  5号线
# 59     257        广州                   地铁6号线                  6号线
# 60     257        广州                   地铁7号线                  7号线
# 61     257        广州                   地铁8号线                  8号线
# 62     257        广州                   地铁9号线                  9号线
# 63     257        广州                  地铁10号线                 10号线
# 64     257        广州                地铁11号线外环                 11号线
# 65     257        广州       地铁12号线(浔峰岗-广州体育馆)      12号线(浔峰岗-广州体育馆)
# 66     257        广州        地铁12号线(二沙岛-大学城南)       12号线(二沙岛-大学城南)
# 67     257        广州                  地铁13号线                 13号线
# 68     257        广州                  地铁14号线                 14号线
# 69     257        广州                地铁14号线支线         14号线支线(知识城线)
# 70     257        广州                  地铁18号线                 18号线
# 71     257        广州                  地铁21号线                 21号线
# 72     257        广州                  地铁22号线                 22号线
# 73     257        广州                 佛山地铁2号线              佛山地铁2号线
# 74     257        广州     佛山地铁3号线(中山公园-顺德学院站)  佛山地铁3号线(中山公园-顺德学院站)
# 75     257        广州     佛山地铁3号线(佛山大学-顺德学院站)     佛山地铁3号线(联和-佛山大学)
# 76     257        广州                     广佛线                  广佛线
# 77     257        广州                    apm线                 APM线
# 78     257        广州               海珠有轨电车1号线            海珠有轨电车1号线
# 79     257        广州               黄埔有轨电车1号线            黄埔有轨电车1号线
# 80     257        广州               黄埔有轨电车2号线            黄埔有轨电车2号线
# 81     257        广州                   东环城际线                东环城际线
# 82     257        广州                   广清城际线                广清城际线
# 83     257        广州                 广肇广惠城际线              广肇广惠城际线
# 84     257        广州                   琶莲城际线                琶莲城际线
#
#     line_is_loop line_label_x line_label_y line_label_rotation line_color  \
# 53             0         -520          250                   0    #ECD35E
# 54             0         -160         -480                   0    #4288B4
# 55             0          230         -300                   0    #EEB56E
# 56             0          -60         -530                   0    #EEB56E
# 57             0         1160          830                   0    #4BA37A
# 58             0          880          300                   0    #D34F6C
# 59             0         -790         -345                   0    #A36E8C
# 60             0          560         -580                   0    #8FC322
# 61             0         -565         -610                   0    #00A1CC
# 62             0         -940         -870                   0    #8DCFAA
# 63             0         -450          260                   0    #7799BF
# 64             1          220         -160                   0    #ECC040
# 65             0         -470         -560                   0    #828757
# 66             0          300          287                   0    #828757
# 67             0         1180         -160                   0    #A2A363
# 68             0          700        -1235                   0    #945253
# 69             0          680       -821.2                   0    #945253
# 70             0          765          800                   0    #7486BD
# 71             0         1230         -700                   0    #4D5068
# 72             0          -70          515                   0    #DD7453
# 73             0        -1180          470                   0    #FF4048
# 74             0         -300          840                   0    #456E9B
# 75             0         -980         -310                   0    #456E9B
# 76             0          -70          275                   0    #CBDE42
# 77             0           65         -260                   0    #58CAE9
# 78             0          420           30                   0    #6EC161
# 79             0          940         -515                   0    #BF635D
# 80             0         1060         -450                   0    #D53C82
# 81             0         -765         -930                   0    #5C82BD
# 82             0        -1060        -1237                   0    #5C82BD
# 83             0        -1100         -620                   0    #5C82BD
# 84             0          490          100                   0    #5C82BD
#
#     line_name_count  line_name_full_count      line_name_branch
# 53                1                     1                   1号线
# 54                1                     1                   2号线
# 55                2                     1         3号线(海傍-天河客运站)
# 56                2                     1  3号线(体育西路-机场北(2号航站楼))
# 57                1                     1                   4号线
# 58                1                     1                   5号线
# 59                1                     1                   6号线
# 60                1                     1                   7号线
# 61                1                     1                   8号线
# 62                1                     1                   9号线
# 63                1                     1                  10号线
# 64                1                     1                  11号线
# 65                1                     1       12号线(浔峰岗-广州体育馆)
# 66                1                     1        12号线(二沙岛-大学城南)
# 67                1                     1                  13号线
# 68                1                     1                  14号线
# 69                1                     1          14号线支线(知识城线)
# 70                1                     1                  18号线
# 71                1                     1                  21号线
# 72                1                     1                  22号线
# 73                1                     1                 佛山2号线
# 74                1                     1     佛山3号线(中山公园-顺德学院站)
# 75                1                     1        佛山3号线(联和-佛山大学)
# 76                1                     1                   广佛线
# 77                1                     1                  APM线
# 78                1                     1             海珠有轨电车1号线
# 79                1                     1             黄埔有轨电车1号线
# 80                1                     1             黄埔有轨电车2号线
# 81                1                     1                 东环城际线
# 82                1                     1                 广清城际线
# 83                1                     1               广肇广惠城际线
# 84                1                     1                 琶莲城际线

# %%
# 按城市，线路顺序添加line_order
df_line['line_order'] = df_line.groupby('city_id').cumcount() + 1
df_line
# Out:
#     city_id city_name line_name_full line_name  line_is_loop line_label_x  \
# 0       131        北京       地铁1号线八通线    1号线八通线             0       -498.9
# 1       131        北京          地铁2号线       2号线             1       -175.3
# 2       131        北京          地铁3号线       3号线             0          450
# 3       131        北京       地铁4号线大兴线    4号线大兴线             0       -499.3
# 4       131        北京          地铁5号线       5号线             0           18
# ..      ...       ...            ...       ...           ...          ...
# 628   51314       马德里            ML1       ML1             0          -70
# 629   51314       马德里            ML2       ML2             0         -780
# 630   51314       马德里            ML3       ML3             0        -1800
# 631   51314       马德里           ML42       ML4             0         -110
# 632   51314       马德里            ML4       ML4             0         -110
#
#     line_label_y line_label_rotation line_color  line_name_count  \
# 0          139.1                   0    #c03935                1
# 1           -4.9                   0    #005f98                1
# 2            -55                   0    #942413                1
# 3           -224                   0    #008e9c                1
# 4         -353.9                   0    #a6217f                1
# ..           ...                 ...        ...              ...
# 628         -960                   0    #5086c2                1
# 629         -280                   0    #ea4d81                1
# 630        295.2                   0    #ff6642                1
# 631         1600                   0    #77b838                2
# 632         1600                   0    #77b838                2
#
#      line_name_full_count line_name_branch  line_order
# 0                       1           1号线八通线           1
# 1                       1              2号线           2
# 2                       1              3号线           3
# 3                       1           4号线大兴线           4
# 4                       1              5号线           5
# ..                    ...              ...         ...
# 628                     1              ML1          13
# 629                     1              ML2          14
# 630                     1              ML3          15
# 631                     1             ML42          16
# 632                     1              ML4          17
#
# [633 rows x 13 columns]

# %% [markdown]
# #### 主线名称清洗
# 1. 计算line_name与上一行相同字数，作为same_prefix_len列
# 2. 筛选出same_prefix_len>2的行，以及每一的上一行
# 3. 将['city_id', 'city_name', 'line_name_full', 'line_name', 'line_name_branch']保存为新的df
# 4. 对比subway_line_fixed.json文件，将新增的手工添加"line_name_main"字段，复制到subway_line_fixed.json文件最后。

# %%
df_line_main = df_line.copy()
# 按城市，统计line_name与上一行line_name相同的字数，从首字开始统计，如首字不同，直接记为0
df_line_main['same_prefix_len'] = 0
for city in df_line_main['city_name'].unique():
    city_mask = df_line_main[df_line_main['city_name'] == city]
    prev_line_name = ""
    for idx, row in city_mask.iterrows():
        line_name = row['line_name']
        if line_name == prev_line_name:
            df_line_main.at[idx, 'same_prefix_len'] = len(line_name)
        else:
            # 计算与上一行相同的前缀长度
            common_length = 0
            for c1, c2 in zip(line_name, prev_line_name):
                if c1 == c2:
                    common_length += 1
                else:
                    break
            df_line_main.at[idx, 'same_prefix_len'] = common_length
        prev_line_name = line_name
df_line_main
# Out:
#     city_id city_name line_name_full line_name  line_is_loop line_label_x  \
# 0       131        北京       地铁1号线八通线    1号线八通线             0       -498.9
# 1       131        北京          地铁2号线       2号线             1       -175.3
# 2       131        北京          地铁3号线       3号线             0          450
# 3       131        北京       地铁4号线大兴线    4号线大兴线             0       -499.3
# 4       131        北京          地铁5号线       5号线             0           18
# ..      ...       ...            ...       ...           ...          ...
# 628   51314       马德里            ML1       ML1             0          -70
# 629   51314       马德里            ML2       ML2             0         -780
# 630   51314       马德里            ML3       ML3             0        -1800
# 631   51314       马德里           ML42       ML4             0         -110
# 632   51314       马德里            ML4       ML4             0         -110
#
#     line_label_y line_label_rotation line_color  line_name_count  \
# 0          139.1                   0    #c03935                1
# 1           -4.9                   0    #005f98                1
# 2            -55                   0    #942413                1
# 3           -224                   0    #008e9c                1
# 4         -353.9                   0    #a6217f                1
# ..           ...                 ...        ...              ...
# 628         -960                   0    #5086c2                1
# 629         -280                   0    #ea4d81                1
# 630        295.2                   0    #ff6642                1
# 631         1600                   0    #77b838                2
# 632         1600                   0    #77b838                2
#
#      line_name_full_count line_name_branch  line_order  same_prefix_len
# 0                       1           1号线八通线           1                0
# 1                       1              2号线           2                0
# 2                       1              3号线           3                0
# 3                       1           4号线大兴线           4                0
# 4                       1              5号线           5                0
# ..                    ...              ...         ...              ...
# 628                     1              ML1          13                0
# 629                     1              ML2          14                2
# 630                     1              ML3          15                2
# 631                     1             ML42          16                2
# 632                     1              ML4          17                3
#
# [633 rows x 14 columns]

# %%
# 筛选出same_prefix_len>2的行，以及每一的上一行
df_line_main_filtered = pd.DataFrame()
for city in df_line_main['city_name'].unique():
    city_mask = df_line_main[df_line_main['city_name'] == city]
    indices = city_mask.index.tolist()
    for i in range(1, len(indices)):
        if city_mask.at[indices[i], 'same_prefix_len'] > 2:
            df_line_main_filtered = pd.concat([df_line_main_filtered, city_mask.loc[[indices[i-1], indices[i]]]])
df_line_main_filtered = df_line_main_filtered.drop_duplicates().reset_index(drop=True)
df_line_main_filtered
# Out:
#     city_id city_name          line_name_full           line_name  \
# 0       131        北京         地铁17号线(十里河-嘉会湖)       17号线(十里河-嘉会湖)
# 1       131        北京  地铁17号线北段(未来科学城北-工人体育场)  17号线(未来科学城北-工人体育场)
# 2       289        上海          地铁5号线(莘庄-奉贤新城)                 5号线
# 3       289        上海      地铁5号线支线(东川路-闵行开发区)               5号线支线
# 4       289        上海         地铁10号线(基隆路-航中路)       10号线(基隆路-航中路)
# ..      ...       ...                     ...                 ...
# 164   51314       马德里                 Line 10             Line 10
# 165   51314       马德里                 Line 11             Line 11
# 166   51314       马德里                 Line 12             Line 12
# 167   51314       马德里                    ML42                 ML4
# 168   51314       马德里                     ML4                 ML4
#
#      line_is_loop line_label_x line_label_y line_label_rotation line_color  \
# 0               0          450          700                   0    #25989A
# 1               0          108         -430                   0    #25989A
# 2               0         -499        987.3                   0    #CC00CC
# 3               0         -589        787.3                   0    #CC00CC
# 4               0         -750         58.8                   0    #C9A7D5
# ..            ...          ...          ...                 ...        ...
# 164             0          380        -1320                   0    #0f6ab0
# 165             0         -700          670                   0    #18a853
# 166             0        -1100          720                   0    #a4991e
# 167             0         -110         1600                   0    #77b838
# 168             0         -110         1600                   0    #77b838
#
#      line_name_count  line_name_full_count    line_name_branch  line_order  \
# 0                  1                     1       17号线(十里河-嘉会湖)          17
# 1                  1                     1  17号线(未来科学城北-工人体育场)          18
# 2                  1                     1                 5号线           5
# 3                  1                     1               5号线支线           6
# 4                  1                     1       10号线(基隆路-航中路)          11
# ..               ...                   ...                 ...         ...
# 164                1                     1             Line 10          10
# 165                1                     1             Line 11          11
# 166                1                     1             Line 12          12
# 167                2                     1                ML42          16
# 168                2                     1                 ML4          17
#
#      same_prefix_len
# 0                  1
# 1                  5
# 2                  0
# 3                  3
# 4                  0
# ..               ...
# 164                5
# 165                6
# 166                6
# 167                2
# 168                3
#
# [169 rows x 14 columns]

# %%
df_line_main_filtered_dict = df_line_main_filtered[['city_id', 'city_name', 'line_name_full', 'line_name', 'line_name_branch']].to_dict(orient='records')
df_line_main_filtered_dict
# Out:
# [{'city_id': '131',
#   'city_name': '北京',
#   'line_name_full': '地铁17号线(十里河-嘉会湖)',
#   'line_name': '17号线(十里河-嘉会湖)',
#   'line_name_branch': '17号线(十里河-嘉会湖)'},
#  {'city_id': '131',
#   'city_name': '北京',
#   'line_name_full': '地铁17号线北段(未来科学城北-工人体育场)',
#   'line_name': '17号线(未来科学城北-工人体育场)',
#   'line_name_branch': '17号线(未来科学城北-工人体育场)'},
#  {'city_id': '289',
#   'city_name': '上海',
#   'line_name_full': '地铁5号线(莘庄-奉贤新城)',
#   'line_name': '5号线',
#   'line_name_branch': '5号线'},
#  {'city_id': '289',
#   'city_name': '上海',
#   'line_name_full': '地铁5号线支线(东川路-闵行开发区)',
#   'line_name': '5号线支线',
#   'line_name_branch': '5号线支线'},
#  {'city_id': '289',
#   'city_name': '上海',
#   'line_name_full': '地铁10号线(基隆路-航中路)',
#   'line_name': '10号线(基隆路-航中路)',
#   'line_name_branch': '10号线(基隆路-航中路)'},
#  {'city_id': '289',
#   'city_name': '上海',
#   'line_name_full': '地铁10号线(基隆路-虹桥火车站)',
#   'line_name': '10号线(基隆路-虹桥火车站)',
#   'line_name_branch': '10号线(基隆路-虹桥火车站)'},
#  {'city_id': '289',
#   'city_name': '上海',
#   'line_name_full': '地铁11号线(嘉定北-迪士尼)',
#   'line_name': '11号线(嘉定北-迪士尼)',
#   'line_name_branch': '11号线(嘉定北-迪士尼)'},
#  {'city_id': '289',
#   'city_name': '上海',
#   'line_name_full': '地铁11号线(花桥-迪士尼)',
#   'line_name': '11号线(花桥-迪士尼)',
#   'line_name_branch': '11号线(花桥-迪士尼)'},
#  {'city_id': '257',
#   'city_name': '广州',
#   'line_name_full': '地铁3号线(海傍-天河客运站)',
#   'line_name': '3号线',
#   'line_name_branch': '3号线(海傍-天河客运站)'},
#  {'city_id': '257',
#   'city_name': '广州',
#   'line_name_full': '地铁3号线(体育西路-机场北(2号航站楼))',
#   'line_name': '3号线',
#   'line_name_branch': '3号线(体育西路-机场北(2号航站楼))'},
#  {'city_id': '257',
#   'city_name': '广州',
#   'line_name_full': '地铁12号线(浔峰岗-广州体育馆)',
#   'line_name': '12号线(浔峰岗-广州体育馆)',
#   'line_name_branch': '12号线(浔峰岗-广州体育馆)'},
#  {'city_id': '257',
#   'city_name': '广州',
#   'line_name_full': '地铁12号线(二沙岛-大学城南)',
#   'line_name': '12号线(二沙岛-大学城南)',
#   'line_name_branch': '12号线(二沙岛-大学城南)'},
#  {'city_id': '257',
#   'city_name': '广州',
#   'line_name_full': '地铁14号线',
#   'line_name': '14号线',
#   'line_name_branch': '14号线'},
#  {'city_id': '257',
#   'city_name': '广州',
#   'line_name_full': '地铁14号线支线',
#   'line_name': '14号线支线(知识城线)',
#   'line_name_branch': '14号线支线(知识城线)'},
#  {'city_id': '257',
#   'city_name': '广州',
#   'line_name_full': '佛山地铁2号线',
#   'line_name': '佛山地铁2号线',
#   'line_name_branch': '佛山2号线'},
#  {'city_id': '257',
#   'city_name': '广州',
#   'line_name_full': '佛山地铁3号线(中山公园-顺德学院站)',
#   'line_name': '佛山地铁3号线(中山公园-顺德学院站)',
#   'line_name_branch': '佛山3号线(中山公园-顺德学院站)'},
#  {'city_id': '257',
#   'city_name': '广州',
#   'line_name_full': '佛山地铁3号线(佛山大学-顺德学院站)',
#   'line_name': '佛山地铁3号线(联和-佛山大学)',
#   'line_name_branch': '佛山3号线(联和-佛山大学)'},
#  {'city_id': '257',
#   'city_name': '广州',
#   'line_name_full': '黄埔有轨电车1号线',
#   'line_name': '黄埔有轨电车1号线',
#   'line_name_branch': '黄埔有轨电车1号线'},
#  {'city_id': '257',
#   'city_name': '广州',
#   'line_name_full': '黄埔有轨电车2号线',
#   'line_name': '黄埔有轨电车2号线',
#   'line_name_branch': '黄埔有轨电车2号线'},
#  {'city_id': '340',
#   'city_name': '深圳',
#   'line_name_full': '地铁6号线',
#   'line_name': '6号线',
#   'line_name_branch': '6号线'},
#  {'city_id': '340',
#   'city_name': '深圳',
#   'line_name_full': '地铁6号线支线',
#   'line_name': '6号线支线',
#   'line_name_branch': '6号线支线'},
#  {'city_id': '340',
#   'city_name': '深圳',
#   'line_name_full': '龙华有轨电车(新澜-清湖)',
#   'line_name': '龙华有轨电车(新澜-清湖)',
#   'line_name_branch': '龙华有轨电车(新澜-清湖)'},
#  {'city_id': '340',
#   'city_name': '深圳',
#   'line_name_full': '龙华有轨电车(清湖-下围)',
#   'line_name': '龙华有轨电车(清湖-下围)',
#   'line_name_branch': '龙华有轨电车(清湖-下围)'},
#  {'city_id': '132',
#   'city_name': '重庆',
#   'line_name_full': '轨道交通3号线(鱼洞-江北机场t2航站楼)',
#   'line_name': '3号线',
#   'line_name_branch': '3号线'},
#  {'city_id': '132',
#   'city_name': '重庆',
#   'line_name_full': '轨道交通3号线(空港线)',
#   'line_name': '3号线(空港线)',
#   'line_name_branch': '3号线(空港线)'},
#  {'city_id': '132',
#   'city_name': '重庆',
#   'line_name_full': '轨道交通6号线',
#   'line_name': '6号线',
#   'line_name_branch': '6号线'},
#  {'city_id': '132',
#   'city_name': '重庆',
#   'line_name_full': '轨道交通6号线延伸段',
#   'line_name': '6号线延伸段',
#   'line_name_branch': '6号线延伸段'},
#  {'city_id': '332',
#   'city_name': '天津',
#   'line_name_full': '轨道交通4号线(东南角-新兴村)',
#   'line_name': '4号线(东南角-新兴村)',
#   'line_name_branch': '4号线(东南角-新兴村)'},
#  {'city_id': '332',
#   'city_name': '天津',
#   'line_name_full': '轨道交通4号线(西站-小街)',
#   'line_name': '4号线(西站-小街)',
#   'line_name_branch': '4号线(西站-小街)'},
#  {'city_id': '332',
#   'city_name': '天津',
#   'line_name_full': '轨道交通6号线',
#   'line_name': '6号线',
#   'line_name_branch': '6号线'},
#  {'city_id': '332',
#   'city_name': '天津',
#   'line_name_full': '轨道交通6号线二期',
#   'line_name': '6号线2期',
#   'line_name_branch': '6号线2期'},
#  {'city_id': '75',
#   'city_name': '成都',
#   'line_name_full': '地铁1号线(五根松-韦家碾)',
#   'line_name': '1号线(五根松-韦家碾)',
#   'line_name_branch': '1号线(五根松-韦家碾)'},
#  {'city_id': '75',
#   'city_name': '成都',
#   'line_name_full': '地铁1号线(科学城-韦家碾)',
#   'line_name': '1号线(科学城-韦家碾)',
#   'line_name_branch': '1号线(科学城-韦家碾)'},
#  {'city_id': '75',
#   'city_name': '成都',
#   'line_name_full': '有轨电车蓉2线(成都西站-郫县西站)',
#   'line_name': '有轨电车蓉2线(成都西站-郫县西站)',
#   'line_name_branch': '有轨电车蓉2线(成都西站-郫县西站)'},
#  {'city_id': '75',
#   'city_name': '成都',
#   'line_name_full': '有轨电车蓉2线(新业路-仁和)',
#   'line_name': '有轨电车蓉2线(新业路-仁和)',
#   'line_name_branch': '有轨电车蓉2线(新业路-仁和)'},
#  {'city_id': '179',
#   'city_name': '杭州',
#   'line_name_full': '地铁3号线(星桥-吴山前村)',
#   'line_name': '3号线(星桥-吴山前村)',
#   'line_name_branch': '3号线(星桥-吴山前村)'},
#  {'city_id': '179',
#   'city_name': '杭州',
#   'line_name_full': '地铁3号线(星桥-石马)',
#   'line_name': '3号线(星桥-石马)',
#   'line_name_branch': '3号线(星桥-石马)'},
#  {'city_id': '179',
#   'city_name': '杭州',
#   'line_name_full': '地铁6号线(枸桔弄-桂花西路)',
#   'line_name': '地铁6号线(枸桔弄-桂花西路)',
#   'line_name_branch': '6号线(枸桔弄-桂花西路)'},
#  {'city_id': '179',
#   'city_name': '杭州',
#   'line_name_full': '地铁6号线(枸桔弄-双浦)',
#   'line_name': '地铁6号线(枸桔弄-双浦)',
#   'line_name_branch': '6号线(枸桔弄-双浦)'},
#  {'city_id': '158',
#   'city_name': '长沙',
#   'line_name_full': '长株潭城际S1线',
#   'line_name': '长株潭城际(S1)',
#   'line_name_branch': '长株潭城际(S1)'},
#  {'city_id': '158',
#   'city_name': '长沙',
#   'line_name_full': '长株潭城际S1线(九郎山-株洲南站)',
#   'line_name': '长株潭城际(S1 九郎山-株洲南站)',
#   'line_name_branch': '长株潭城际(S1 九郎山-株洲南站)'},
#  {'city_id': '167',
#   'city_name': '大连',
#   'line_name_full': '地铁3号线(金石滩-大连火车站)',
#   'line_name': '3号线',
#   'line_name_branch': '3号线'},
#  {'city_id': '167',
#   'city_name': '大连',
#   'line_name_full': '地铁3号线(九里)支线',
#   'line_name': '3号线(九里)支线',
#   'line_name_branch': '3号线(九里)支线'},
#  {'city_id': '104',
#   'city_name': '昆明',
#   'line_name_full': '地铁1号线',
#   'line_name': '1号线(环城南路-大学城南)',
#   'line_name_branch': '1号线(环城南路-大学城南)'},
#  {'city_id': '104',
#   'city_name': '昆明',
#   'line_name_full': '地铁1号线支线',
#   'line_name': '1号线支线(昆明南火车站-春融街)',
#   'line_name_branch': '1号线支线(昆明南火车站-春融街)'},
#  {'city_id': '138',
#   'city_name': '佛山',
#   'line_name_full': '佛山地铁3号线(佛山大学-顺德学院站)',
#   'line_name': '3号线(顺德学院站-中山公园)',
#   'line_name_branch': '3号线(顺德学院站-中山公园)'},
#  {'city_id': '138',
#   'city_name': '佛山',
#   'line_name_full': '佛山地铁3号线(顺德学院站-佛山大学)',
#   'line_name': '3号线(联和-佛山大学)',
#   'line_name_branch': '3号线(联和-佛山大学)'},
#  {'city_id': '236',
#   'city_name': '青岛',
#   'line_name_full': '地铁11号线',
#   'line_name': '地铁11号线(蓝谷快线)',
#   'line_name_branch': '11号线(蓝谷快线)'},
#  {'city_id': '236',
#   'city_name': '青岛',
#   'line_name_full': '地铁13号线',
#   'line_name': '地铁13号线(西海岸快线)',
#   'line_name_branch': '13号线(西海岸快线)'},
#  {'city_id': '127',
#   'city_name': '合肥',
#   'line_name_full': '轨道交通4号线',
#   'line_name': '4号线',
#   'line_name_branch': '4号线'},
#  {'city_id': '127',
#   'city_name': '合肥',
#   'line_name_full': '轨道交通4号线南延线',
#   'line_name': '4号线南延线',
#   'line_name_branch': '4号线南延线'},
#  {'city_id': '2912',
#   'city_name': '香港特别行政区',
#   'line_name_full': '将军澳线(北角-宝琳)',
#   'line_name': '将军澳线(北角-宝琳)',
#   'line_name_branch': '将军澳线(北角-宝琳)'},
#  {'city_id': '2912',
#   'city_name': '香港特别行政区',
#   'line_name_full': '将军澳线(北角-康城)',
#   'line_name': '将军澳线(北角-康城)',
#   'line_name_branch': '将军澳线(北角-康城)'},
#  {'city_id': '2912',
#   'city_name': '香港特别行政区',
#   'line_name_full': '东铁线(金钟-罗湖)',
#   'line_name': '东铁线(金钟-罗湖)',
#   'line_name_branch': '东铁线(金钟-罗湖)'},
#  {'city_id': '2912',
#   'city_name': '香港特别行政区',
#   'line_name_full': '东铁线(金钟-落马洲)',
#   'line_name': '东铁线(金钟-落马洲)',
#   'line_name_branch': '东铁线(金钟-落马洲)'},
#  {'city_id': '9002',
#   'city_name': '台北',
#   'line_name_full': 'O中和新芦线(芦洲-南势角)',
#   'line_name': 'O中和新芦线(芦洲-南势角)',
#   'line_name_branch': 'O中和新芦线(芦洲-南势角)'},
#  {'city_id': '9002',
#   'city_name': '台北',
#   'line_name_full': 'O中和新芦线(回龙-南势角)',
#   'line_name': 'O中和新芦线(回龙-南势角)',
#   'line_name_branch': 'O中和新芦线(回龙-南势角)'},
#  {'city_id': '9002',
#   'city_name': '台北',
#   'line_name_full': 'A桃园机场捷运普通车',
#   'line_name': 'A桃园机场捷运普通车',
#   'line_name_branch': 'A桃园机场捷运普通车'},
#  {'city_id': '9002',
#   'city_name': '台北',
#   'line_name_full': 'A桃园机场捷运直达车',
#   'line_name': 'A桃园机场捷运直达车',
#   'line_name_branch': 'A桃园机场捷运直达车'},
#  {'city_id': '333',
#   'city_name': '金华',
#   'line_name_full': '轨道交通金义东线金义段',
#   'line_name': '金义东线金义段',
#   'line_name_branch': '金义东线金义段'},
#  {'city_id': '333',
#   'city_name': '金华',
#   'line_name_full': '轨道交通金义东线义东段',
#   'line_name': '金义东线义东段',
#   'line_name_branch': '金义东线义东段'},
#  {'city_id': '293',
#   'city_name': '绍兴',
#   'line_name_full': '绍兴地铁1号线',
#   'line_name': '绍兴地铁1号线',
#   'line_name_branch': '绍兴1号线'},
#  {'city_id': '293',
#   'city_name': '绍兴',
#   'line_name_full': '绍兴地铁1号线支线',
#   'line_name': '绍兴地铁1号线支线',
#   'line_name_branch': '绍兴1号线支线'},
#  {'city_id': '293',
#   'city_name': '绍兴',
#   'line_name_full': '绍兴地铁2号线',
#   'line_name': '绍兴地铁2号线',
#   'line_name_branch': '绍兴2号线'},
#  {'city_id': '20001',
#   'city_name': '新加坡',
#   'line_name_full': 'North East Line',
#   'line_name': 'North East Line',
#   'line_name_branch': 'North East Line'},
#  {'city_id': '20001',
#   'city_name': '新加坡',
#   'line_name_full': 'North South Line',
#   'line_name': 'North South Line',
#   'line_name_branch': 'North South Line'},
#  {'city_id': '20508',
#   'city_name': '曼谷',
#   'line_name_full': 'BTS Silom Line',
#   'line_name': 'BTS Silom Line',
#   'line_name_branch': 'BTS Silom Line'},
#  {'city_id': '20508',
#   'city_name': '曼谷',
#   'line_name_full': 'BTS Sukhumvit Line',
#   'line_name': 'BTS Sukhumvit Line',
#   'line_name_branch': 'BTS Sukhumvit Line'},
#  {'city_id': '20508',
#   'city_name': '曼谷',
#   'line_name_full': 'Airport City Line',
#   'line_name': 'Airport City Line',
#   'line_name_branch': 'Airport City Line'},
#  {'city_id': '20508',
#   'city_name': '曼谷',
#   'line_name_full': 'Airport Express Line',
#   'line_name': 'Airport Express Line',
#   'line_name_branch': 'Airport Express Line'},
#  {'city_id': '26041',
#   'city_name': '东京',
#   'line_name_full': '大江户线',
#   'line_name': '大江户线',
#   'line_name_branch': '大江户线'},
#  {'city_id': '26041',
#   'city_name': '东京',
#   'line_name_full': '大江户线环线',
#   'line_name': '大江户线环线',
#   'line_name_branch': '大江户线环线'},
#  {'city_id': '26041',
#   'city_name': '东京',
#   'line_name_full': '丸之内线',
#   'line_name': '丸之内线',
#   'line_name_branch': '丸之内线'},
#  {'city_id': '26041',
#   'city_name': '东京',
#   'line_name_full': '丸之内线支线',
#   'line_name': '丸之内线支线',
#   'line_name_branch': '丸之内线支线'},
#  {'city_id': '30016',
#   'city_name': '首尔',
#   'line_name_full': '1号线(光明-永登浦)',
#   'line_name': '1号线(光明-永登浦)',
#   'line_name_branch': '1号线(光明-永登浦)'},
#  {'city_id': '30016',
#   'city_name': '首尔',
#   'line_name_full': '1号线(光云大学-西东滩)',
#   'line_name': '1号线(光云大学-西东滩)',
#   'line_name_branch': '1号线(光云大学-西东滩)'},
#  {'city_id': '30016',
#   'city_name': '首尔',
#   'line_name_full': '1号线(清凉里-新昌)',
#   'line_name': '1号线(清凉里-新昌)',
#   'line_name_branch': '1号线(清凉里-新昌)'},
#  {'city_id': '30016',
#   'city_name': '首尔',
#   'line_name_full': '1号线(仁川-逍遥山)',
#   'line_name': '1号线(仁川-逍遥山)',
#   'line_name_branch': '1号线(仁川-逍遥山)'},
#  {'city_id': '30016',
#   'city_name': '首尔',
#   'line_name_full': '2号线(喜鹊山-新道林)',
#   'line_name': '2号线(喜鹊山-新道林)',
#   'line_name_branch': '2号线(喜鹊山-新道林)'},
#  {'city_id': '30016',
#   'city_name': '首尔',
#   'line_name_full': '2号线(新设洞-圣水)',
#   'line_name': '2号线(新设洞-圣水)',
#   'line_name_branch': '2号线(新设洞-圣水)'},
#  {'city_id': '30016',
#   'city_name': '首尔',
#   'line_name_full': '2号线(圣水-圣水)',
#   'line_name': '2号线(圣水-圣水)',
#   'line_name_branch': '2号线(圣水-圣水)'},
#  {'city_id': '30016',
#   'city_name': '首尔',
#   'line_name_full': '5号线(傍花-马川)',
#   'line_name': '5号线(傍花-马川)',
#   'line_name_branch': '5号线(傍花-马川)'},
#  {'city_id': '30016',
#   'city_name': '首尔',
#   'line_name_full': '5号线(傍花-河南丰山)',
#   'line_name': '5号线(傍花-河南丰山)',
#   'line_name_branch': '5号线(傍花-河南丰山)'},
#  {'city_id': '30016',
#   'city_name': '首尔',
#   'line_name_full': 'K京义中央线(砥平-汶山)',
#   'line_name': 'K京义中央线(砥平-汶山)',
#   'line_name_branch': 'K京义中央线(砥平-汶山)'},
#  {'city_id': '30016',
#   'city_name': '首尔',
#   'line_name_full': 'K京义中央线(汶山-首尔站)',
#   'line_name': 'K京义中央线(汶山-首尔站)',
#   'line_name_branch': 'K京义中央线(汶山-首尔站)'},
#  {'city_id': '49872',
#   'city_name': '巴黎',
#   'line_name_full': '13(La Fourche-Saint.Denis Université)',
#   'line_name': '13号线(La Fourche-Saint.Denis Université)',
#   'line_name_branch': '13号线(La Fourche-Saint.Denis Université)'},
#  {'city_id': '49872',
#   'city_name': '巴黎',
#   'line_name_full': '13(Chatillon Montrouge-Asnières Gennevilliers Les Courtilles)',
#   'line_name': '13号线(Chatillon Montrouge-Asnières Gennevilliers Les Courtilles)',
#   'line_name_branch': '13号线(Chatillon Montrouge-Asnières Gennevilliers Les Courtilles)'},
#  {'city_id': '39816',
#   'city_name': '里约热内卢',
#   'line_name_full': 'Line 1',
#   'line_name': 'Line 1',
#   'line_name_branch': 'Line 1'},
#  {'city_id': '39816',
#   'city_name': '里约热内卢',
#   'line_name_full': 'Line 2',
#   'line_name': 'Line 2',
#   'line_name_branch': 'Line 2'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 1',
#   'line_name': 'Line 1',
#   'line_name_branch': 'Line 1'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 2',
#   'line_name': 'Line 2',
#   'line_name_branch': 'Line 2'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 3',
#   'line_name': 'Line 3',
#   'line_name_branch': 'Line 3'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 4',
#   'line_name': 'Line 4',
#   'line_name_branch': 'Line 4'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 5',
#   'line_name': 'Line 5',
#   'line_name_branch': 'Line 5'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 7',
#   'line_name': 'Line 7',
#   'line_name_branch': 'Line 7'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 8',
#   'line_name': 'Line 8',
#   'line_name_branch': 'Line 8'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 9',
#   'line_name': 'Line 9',
#   'line_name_branch': 'Line 9'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 10',
#   'line_name': 'Line 10',
#   'line_name_branch': 'Line 10'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 11',
#   'line_name': 'Line 11',
#   'line_name_branch': 'Line 11'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 11 Expresso',
#   'line_name': 'Line 11 Expresso',
#   'line_name_branch': 'Line 11 Expresso'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 12',
#   'line_name': 'Line 12',
#   'line_name_branch': 'Line 12'},
#  {'city_id': '39817',
#   'city_name': '圣保罗',
#   'line_name_full': 'Line 15',
#   'line_name': 'Line 15',
#   'line_name_branch': 'Line 15'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line 1',
#   'line_name': 'Line 1',
#   'line_name_branch': 'Line 1'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line 2',
#   'line_name': 'Line 2',
#   'line_name_branch': 'Line 2'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line 3',
#   'line_name': 'Line 3',
#   'line_name_branch': 'Line 3'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line 4',
#   'line_name': 'Line 4',
#   'line_name_branch': 'Line 4'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line 6',
#   'line_name': 'Line 6',
#   'line_name_branch': 'Line 6'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line 7',
#   'line_name': 'Line 7',
#   'line_name_branch': 'Line 7'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line B',
#   'line_name': 'Line B',
#   'line_name_branch': 'Line B'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line C',
#   'line_name': 'Line C',
#   'line_name_branch': 'Line C'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line D',
#   'line_name': 'Line D',
#   'line_name_branch': 'Line D'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line E',
#   'line_name': 'Line E',
#   'line_name_branch': 'Line E'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line F',
#   'line_name': 'Line F',
#   'line_name_branch': 'Line F'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line G',
#   'line_name': 'Line G',
#   'line_name_branch': 'Line G'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line J',
#   'line_name': 'Line J',
#   'line_name_branch': 'Line J'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line L',
#   'line_name': 'Line L',
#   'line_name_branch': 'Line L'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line M',
#   'line_name': 'Line M',
#   'line_name_branch': 'Line M'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line N',
#   'line_name': 'Line N',
#   'line_name_branch': 'Line N'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line Q',
#   'line_name': 'Line Q',
#   'line_name_branch': 'Line Q'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line W',
#   'line_name': 'Line W',
#   'line_name_branch': 'Line W'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line R',
#   'line_name': 'Line R',
#   'line_name_branch': 'Line R'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line Z',
#   'line_name': 'Line Z',
#   'line_name_branch': 'Line Z'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line S1',
#   'line_name': 'Line S1',
#   'line_name_branch': 'Line S1'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line S2',
#   'line_name': 'Line S2',
#   'line_name_branch': 'Line S2'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line S3',
#   'line_name': 'Line S3',
#   'line_name_branch': 'Line S3'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'AirTrain JFK Red',
#   'line_name': 'AirTrain JFK Red',
#   'line_name_branch': 'AirTrain JFK Red'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'AirTrain JFK Green',
#   'line_name': 'AirTrain JFK Green',
#   'line_name_branch': 'AirTrain JFK Green'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'AirTrain JFK Gold',
#   'line_name': 'AirTrain JFK Gold',
#   'line_name_branch': 'AirTrain JFK Gold'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line A(Ozone Park/Lefferts Blvd-Rockaway Blvd)',
#   'line_name': 'Line A(Ozone Park/Lefferts Blvd-Rockaway Blvd)',
#   'line_name_branch': 'Line A(Ozone Park/Lefferts Blvd-Rockaway Blvd)'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line A(Rockaway Blvd-Inwood/207 St)',
#   'line_name': 'Line A(Rockaway Blvd-Inwood/207 St)',
#   'line_name_branch': 'Line A(Rockaway Blvd-Inwood/207 St)'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line A(Broad Channel-Rockaway Park/Beach 116 St)',
#   'line_name': 'Line A(Broad Channel-Rockaway Park/Beach 116 St)',
#   'line_name_branch': 'Line A(Broad Channel-Rockaway Park/Beach 116 St)'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line A(Far Rockaway/Mott Av-Rockaway Blvd)',
#   'line_name': 'Line A(Far Rockaway/Mott Av-Rockaway Blvd)',
#   'line_name_branch': 'Line A(Far Rockaway/Mott Av-Rockaway Blvd)'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line 5(Nereid Av-E 180 St)',
#   'line_name': 'Line 5(Nereid Av-E 180 St)',
#   'line_name_branch': 'Line 5(Nereid Av-E 180 St)'},
#  {'city_id': '60732',
#   'city_name': '纽约',
#   'line_name_full': 'Line 5(Eastchester/Dyre Av-Flatbush Av/Brooklyn College)',
#   'line_name': 'Line 5(Eastchester/Dyre Av-Flatbush Av/Brooklyn College)',
#   'line_name_branch': 'Line 5(Eastchester/Dyre Av-Flatbush Av/Brooklyn College)'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 1',
#   'line_name': 'Line 1',
#   'line_name_branch': 'Line 1'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 2',
#   'line_name': 'Line 2',
#   'line_name_branch': 'Line 2'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 3',
#   'line_name': 'Line 3',
#   'line_name_branch': 'Line 3'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 4(昆采沃-亚历山大公园)',
#   'line_name': 'Line 4',
#   'line_name_branch': 'Line 4(昆采沃-亚历山大公园)'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 4(国际-基辅)',
#   'line_name': 'Line 4',
#   'line_name_branch': 'Line 4(国际-基辅)'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 5',
#   'line_name': 'Line 5',
#   'line_name_branch': 'Line 5'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 6',
#   'line_name': 'Line 6',
#   'line_name_branch': 'Line 6'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 7',
#   'line_name': 'Line 7',
#   'line_name_branch': 'Line 7'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 8',
#   'line_name': 'Line 8',
#   'line_name_branch': 'Line 8'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 8A',
#   'line_name': 'Line 8A',
#   'line_name_branch': 'Line 8A'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 9',
#   'line_name': 'Line 9',
#   'line_name_branch': 'Line 9'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 10',
#   'line_name': 'Line 10',
#   'line_name_branch': 'Line 10'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 11A',
#   'line_name': 'Line 11A',
#   'line_name_branch': 'Line 11A'},
#  {'city_id': '65531',
#   'city_name': '莫斯科',
#   'line_name_full': 'Line 12',
#   'line_name': 'Line 12',
#   'line_name_branch': 'Line 12'},
#  {'city_id': '52390',
#   'city_name': '鹿特丹',
#   'line_name_full': 'Line A',
#   'line_name': 'Line A',
#   'line_name_branch': 'Line A'},
#  {'city_id': '52390',
#   'city_name': '鹿特丹',
#   'line_name_full': 'Line B',
#   'line_name': 'Line B',
#   'line_name_branch': 'Line B'},
#  {'city_id': '52390',
#   'city_name': '鹿特丹',
#   'line_name_full': 'Line C',
#   'line_name': 'Line C',
#   'line_name_branch': 'Line C'},
#  {'city_id': '52390',
#   'city_name': '鹿特丹',
#   'line_name_full': 'Line D',
#   'line_name': 'Line D',
#   'line_name_branch': 'Line D'},
#  {'city_id': '52390',
#   'city_name': '鹿特丹',
#   'line_name_full': 'Line E',
#   'line_name': 'Line E',
#   'line_name_branch': 'Line E'},
#  {'city_id': '51271',
#   'city_name': '巴塞罗那',
#   'line_name_full': 'L10S',
#   'line_name': 'L10S',
#   'line_name_branch': 'L10S'},
#  {'city_id': '51271',
#   'city_name': '巴塞罗那',
#   'line_name_full': 'L10N',
#   'line_name': 'L10N',
#   'line_name_branch': 'L10N'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 1',
#   'line_name': 'Line 1',
#   'line_name_branch': 'Line 1'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 2',
#   'line_name': 'Line 2',
#   'line_name_branch': 'Line 2'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 3',
#   'line_name': 'Line 3',
#   'line_name_branch': 'Line 3'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 4',
#   'line_name': 'Line 4',
#   'line_name_branch': 'Line 4'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 5',
#   'line_name': 'Line 5',
#   'line_name_branch': 'Line 5'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 6',
#   'line_name': 'Line 6',
#   'line_name_branch': 'Line 6'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 7',
#   'line_name': 'Line 7',
#   'line_name_branch': 'Line 7'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 8',
#   'line_name': 'Line 8',
#   'line_name_branch': 'Line 8'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 9',
#   'line_name': 'Line 9',
#   'line_name_branch': 'Line 9'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 10',
#   'line_name': 'Line 10',
#   'line_name_branch': 'Line 10'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 11',
#   'line_name': 'Line 11',
#   'line_name_branch': 'Line 11'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'Line 12',
#   'line_name': 'Line 12',
#   'line_name_branch': 'Line 12'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'ML42',
#   'line_name': 'ML4',
#   'line_name_branch': 'ML42'},
#  {'city_id': '51314',
#   'city_name': '马德里',
#   'line_name_full': 'ML4',
#   'line_name': 'ML4',
#   'line_name_branch': 'ML4'}]

# %%
with open("subway_line_fixed.json", "r", encoding="utf-8") as f:
    subway_line_fixed = json.load(f)
# 对比subway_line_fixed.json文件，打印df_line_main_filtered_dict中每项前4项不在subway_line_fixed中的行
fields = ['city_id', 'city_name', 'line_name_full', 'line_name']
fixed_set = set(
    tuple(line[field] for field in fields)
    for line in subway_line_fixed
)
for item in df_line_main_filtered_dict:
    key = tuple(item[field] for field in fields)
    if key not in fixed_set:
        print(item)
# 手动为上述打印的行添加"line_name_main"字段，复制到subway_line_fixed.json文件最后
# 保存subway_line_fixed.json文件

# %% [markdown]
# #### 合并线路数据

# %%
with open("subway_line_fixed.json", "r", encoding="utf-8") as f:
    subway_line_fixed = json.load(f)
subway_line_fixed_df = pd.DataFrame.from_dict(subway_line_fixed)
subway_line_fixed_df
# Out:
#     city_id city_name          line_name_full           line_name  \
# 0       131        北京         地铁17号线(十里河-嘉会湖)       17号线(十里河-嘉会湖)
# 1       131        北京  地铁17号线北段(未来科学城北-工人体育场)  17号线(未来科学城北-工人体育场)
# 2       289        上海          地铁5号线(莘庄-奉贤新城)                 5号线
# 3       289        上海      地铁5号线支线(东川路-闵行开发区)               5号线支线
# 4       289        上海         地铁10号线(基隆路-航中路)       10号线(基隆路-航中路)
# ..      ...       ...                     ...                 ...
# 164   51314       马德里                 Line 10             Line 10
# 165   51314       马德里                 Line 11             Line 11
# 166   51314       马德里                 Line 12             Line 12
# 167   51314       马德里                    ML42                 ML4
# 168   51314       马德里                     ML4                 ML4
#
#        line_name_branch line_name_main
# 0         17号线(十里河-嘉会湖)           17号线
# 1    17号线(未来科学城北-工人体育场)           17号线
# 2                   5号线            5号线
# 3                 5号线支线            5号线
# 4         10号线(基隆路-航中路)           10号线
# ..                  ...            ...
# 164             Line 10        Line 10
# 165             Line 11        Line 11
# 166             Line 12        Line 12
# 167                ML42            ML4
# 168                 ML4            ML4
#
# [169 rows x 6 columns]

# %%
dwd_subway_bd_line = df_line.merge(subway_line_fixed_df[['city_id', 'line_name_full', 'line_name_main']], how='left', on=['city_id', 'line_name_full']) 
# 将line_name_main中缺失值，填充为line_name_branch
dwd_subway_bd_line['line_name_main'] = dwd_subway_bd_line['line_name_main'].fillna(dwd_subway_bd_line['line_name_branch'])
dwd_subway_bd_line
# Out:
#     city_id city_name line_name_full line_name  line_is_loop line_label_x  \
# 0       131        北京       地铁1号线八通线    1号线八通线             0       -498.9
# 1       131        北京          地铁2号线       2号线             1       -175.3
# 2       131        北京          地铁3号线       3号线             0          450
# 3       131        北京       地铁4号线大兴线    4号线大兴线             0       -499.3
# 4       131        北京          地铁5号线       5号线             0           18
# ..      ...       ...            ...       ...           ...          ...
# 628   51314       马德里            ML1       ML1             0          -70
# 629   51314       马德里            ML2       ML2             0         -780
# 630   51314       马德里            ML3       ML3             0        -1800
# 631   51314       马德里           ML42       ML4             0         -110
# 632   51314       马德里            ML4       ML4             0         -110
#
#     line_label_y line_label_rotation line_color  line_name_count  \
# 0          139.1                   0    #c03935                1
# 1           -4.9                   0    #005f98                1
# 2            -55                   0    #942413                1
# 3           -224                   0    #008e9c                1
# 4         -353.9                   0    #a6217f                1
# ..           ...                 ...        ...              ...
# 628         -960                   0    #5086c2                1
# 629         -280                   0    #ea4d81                1
# 630        295.2                   0    #ff6642                1
# 631         1600                   0    #77b838                2
# 632         1600                   0    #77b838                2
#
#      line_name_full_count line_name_branch  line_order line_name_main
# 0                       1           1号线八通线           1         1号线八通线
# 1                       1              2号线           2            2号线
# 2                       1              3号线           3            3号线
# 3                       1           4号线大兴线           4         4号线大兴线
# 4                       1              5号线           5            5号线
# ..                    ...              ...         ...            ...
# 628                     1              ML1          13            ML1
# 629                     1              ML2          14            ML2
# 630                     1              ML3          15            ML3
# 631                     1             ML42          16            ML4
# 632                     1              ML4          17            ML4
#
# [633 rows x 14 columns]

# %% [markdown]
# ### 车站表

# %%
def get_dwd_subway_st(df, df_line, is_all_st=True):
    """
    获取地铁站数据
    车站含虚拟车站和真实车站两种
    is_all_st: True-全量车站， False-真实车站
    df: dwd_subway数据
    df_line: dwd_subway_bd_line数据
    """
    df = df.copy() if is_all_st else df[df['st_is_station'] == 1].copy()
    print(f"Total stations: {len(df)}")
    # 连接查询线路顺序
    res_df = df.merge(df_line[['city_id', 'line_name_full', 'line_order', 'line_name_branch', 'line_name_main']], how='left', on=['city_id', 'line_name_full'])
    print(f"Total stations after merge line info: {len(res_df)}")
    # 当len(res_df != len(df))时，说明有部分站点的line_name_full在df_line中没有匹配上
    if len(res_df) != len(df):
        print(f"WARNNING!, Stations with unmatched line info: {len(res_df) - len(df)}")
    # 车站顺序
    res_df['st_order'] = res_df.groupby(['city_id', 'line_name_full']).cumcount() + 1
    # 车站id
    res_df['st_id_virtual'] = res_df.apply(lambda row: f"{row['city_id']}_{row['line_order']:03d}_{row['st_order']:03d}", axis=1)
    # 将st_name为空或字符串长度为0的站点st_name填充为st_id_virtual
    res_df['st_name'] = res_df['st_name'].replace('', np.nan)
    res_df['st_name'] = res_df['st_name'].fillna(res_df['st_id_virtual'])
    # 下一站id
    res_df['target_st_id_virtual'] = res_df.groupby(['city_id', 'line_name_full'])['st_id_virtual'].shift(-1)
    # 如果line_is_loop为1，则最后一站的下一站为第一站
    # 找出所有环线线路
    loop_keys = res_df.loc[res_df['line_is_loop'] == 1, ['city_id', 'line_name_full']].drop_duplicates()

    for _, row in loop_keys.iterrows():
        mask = (res_df['city_id'] == row['city_id']) & (res_df['line_name_full'] == row['line_name_full'])
        idx = res_df.loc[mask].index

        if len(idx) > 1:  # 至少要有两站才能构成环线
            first_idx = idx[0]
            last_idx = idx[-1]
            res_df.loc[last_idx, 'target_st_id_virtual'] = res_df.loc[first_idx, 'st_id_virtual']
    # 按target_st_id_virtual， 添加target_st_name, target_st_x, target_st_y
    res_df = res_df.merge(res_df[['st_id_virtual', 'st_name', 'st_x', 'st_y']].rename(columns={
        'st_id_virtual': 'target_st_id_virtual',
        'st_name': 'target_st_name',
        'st_x': 'target_st_x',
        'st_y': 'target_st_y'
    }), how='left', on='target_st_id_virtual')
    return res_df

# %% [markdown]
# #### 全量车站表
# 含虚拟车站，用于线条更柔和

# %%
df_st_all =  get_dwd_subway_st(dwd_subway, dwd_subway_bd_line, is_all_st=True)
# Out:
# Total stations: 15923
# Total stations after merge line info: 15923

# %% [markdown]
# #### 真实车站表
# 真实存在的， 即st_is_station == 1

# %%
df_st_real =  get_dwd_subway_st(dwd_subway, dwd_subway_bd_line, is_all_st=False)
# Out:
# Total stations: 13291
# Total stations after merge line info: 13291

# %% [markdown]
# ## ADS
# ADS 层（Application Data Store，应用数据层）
#
# 面向应用和报表的最终数据，通常是宽表、指标表。
#
# 特点：与具体应用、报表或接口一一对应。
#
# 作用：满足业务方“即取即用”，保证查询效率。

# %% [markdown]
# 按城市统计指标

# %%
df_st_real
# Out:
#       city_id city_name city_name_e line_name_full line_name  line_show_label  \
# 0         131        北京     beijing       地铁1号线八通线    1号线八通线                0
# 1         131        北京     beijing       地铁1号线八通线    1号线八通线                0
# 2         131        北京     beijing       地铁1号线八通线    1号线八通线                0
# 3         131        北京     beijing       地铁1号线八通线    1号线八通线                0
# 4         131        北京     beijing       地铁1号线八通线    1号线八通线                0
# ...       ...       ...         ...            ...       ...              ...
# 13286   51314       马德里      madeli            ML4       ML4                0
# 13287   51314       马德里      madeli            ML4       ML4                0
# 13288   51314       马德里      madeli            ML4       ML4                0
# 13289   51314       马德里      madeli            ML4       ML4                0
# 13290   51314       马德里      madeli            ML4       ML4                0
#
#       line_n  line_is_loop line_label_x line_label_y  ... crawler_date  \
# 0         23             0       -498.9        139.1  ...   2025-09-28
# 1         23             0       -498.9        139.1  ...   2025-09-28
# 2         23             0       -498.9        139.1  ...   2025-09-28
# 3         23             0       -498.9        139.1  ...   2025-09-28
# 4         23             0       -498.9        139.1  ...   2025-09-28
# ...      ...           ...          ...          ...  ...          ...
# 13286     16             0         -110         1600  ...   2025-09-28
# 13287     16             0         -110         1600  ...   2025-09-28
# 13288     16             0         -110         1600  ...   2025-09-28
# 13289     16             0         -110         1600  ...   2025-09-28
# 13290     16             0         -110         1600  ...   2025-09-28
#
#                   uid line_order line_name_branch st_order  st_id_virtual  \
# 0          1312509280          1           1号线八通线        1    131_001_001
# 1          1312509281          1           1号线八通线        2    131_001_002
# 2          1312509282          1           1号线八通线        3    131_001_003
# 3          1312509283          1           1号线八通线        4    131_001_004
# 4          1312509284          1           1号线八通线        5    131_001_005
# ...               ...        ...              ...      ...            ...
# 13286  51314250928440         17              ML4       12  51314_017_012
# 13287  51314250928443         17              ML4       13  51314_017_013
# 13288  51314250928447         17              ML4       14  51314_017_014
# 13289  51314250928448         17              ML4       15  51314_017_015
# 13290  51314250928449         17              ML4       16  51314_017_016
#
#       target_st_id_virtual                       target_st_name target_st_x  \
# 0              131_001_002                                八角游乐园      -608.2
# 1              131_001_003                                  八宝山      -549.2
# 2              131_001_004                                  玉泉路      -501.8
# 3              131_001_005                                  五棵松      -453.8
# 4              131_001_006                                  万寿路      -409.2
# ...                    ...                                  ...         ...
# 13286        51314_017_013  Poligono Industrial Ciudad de Parla      -261.4
# 13287        51314_017_014                          Jaime I Sur        -320
# 13288        51314_017_015                   Estrella Polar Sur        -320
# 13289        51314_017_016                            Venus Sur        -320
# 13290                  NaN                                  NaN         NaN
#
#       target_st_y
# 0           170.6
# 1           170.6
# 2           170.6
# 3           170.6
# 4           170.6
# ...           ...
# 13286      1434.8
# 13287      1494.8
# 13288      1556.1
# 13289      1616.8
# 13290         NaN
#
# [13291 rows x 41 columns]

# %%
with open("subway_line_to_fix.json", "w", encoding="utf-8") as f:
    json.dump(df_line_main_filtered_dict, f, ensure_ascii=False, indent=4)
